# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier #决策树分类
import sklearn.datasets as datasets
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeRegressor #决策树回归
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = 200*np.random.rand(100, 1) - 100
x
# Out:
# array([[-74.84520954],
#        [-71.32444053],
#        [ 75.34417907],
#        [-84.14729259],
#        [-91.38766552],
#        [-79.8943894 ],
#        [-44.26411725],
#        [ 88.95451379],
#        [-91.18378687],
#        [-72.10423229],
#        [ 51.86201762],
#        [ 27.14730156],
#        [-96.52156328],
#        [-73.52773654],
#        [ 22.91712816],
#        [-91.73565079],
#        [ 71.58278732],
#        [ 64.7961046 ],
#        [-95.12345883],
#        [ 92.71752973],
#        [-34.64969017],
#        [-23.49570357],
#        [-87.28548155],
#        [ 62.93217911],
#        [ 39.13178169],
#        [ 96.86592127],
#        [ 96.1470864 ],
#        [-20.16859543],
#        [-71.7792529 ],
#        [  5.33053705],
#        [ 23.00713955],
#        [-16.13468383],
#        [-61.83065804],
#        [ 87.97975515],
#        [ 98.37794005],
#        [-34.57106343],
#        [-74.01353016],
#        [-42.82717317],
#        [-70.11596317],
#        [ 27.00455635],
#        [-38.66665327],
#        [ 32.74676298],
#        [-68.86836292],
#        [ 48.71894228],
#        [  0.73840564],
#        [ -5.61211391],
#        [-34.5240855 ],
#        [ 28.56720863],
#        [  5.92687727],
#        [ 95.81334007],
#        [ -4.02621318],
#        [-39.86438207],
#        [-40.71694255],
#        [ -5.52888468],
#        [-46.73031743],
#        [  4.37519797],
#        [-90.61571309],
#        [ 85.18453934],
#        [-52.6924566 ],
#        [-45.08606882],
#        [ -9.1782014 ],
#        [-33.71639317],
#        [-53.18533166],
#        [-79.47407608],
#        [ 71.15373798],
#        [ 63.47776206],
#        [-47.29508955],
#        [ 52.80353007],
#        [-96.18771046],
#        [-44.53910909],
#        [-82.2825056 ],
#        [ 61.69524493],
#        [ 32.27512104],
#        [ 73.03922145],
#        [-84.85142967],
#        [ -0.63968035],
#        [ 40.09688125],
#        [ 12.22043278],
#        [ -6.55072134],
#        [-28.68401095],
#        [  4.17045507],
#        [ 45.85687543],
#        [-61.24383385],
#        [ 16.00786002],
#        [-68.03979318],
#        [-82.10240859],
#        [  8.17827962],
#        [ 53.45546672],
#        [ 47.19991741],
#        [ 41.86066113],
#        [ 64.32498458],
#        [-84.31679612],
#        [ 76.47233208],
#        [-80.48408121],
#        [ 14.10955994],
#        [-43.81021203],
#        [-70.56327712],
#        [ 34.35018299],
#        [ 78.31537347],
#        [ 94.17138509]])

# %%
x_train = np.sort(x, axis=0)
x_train
# Out:
# array([[-96.52156328],
#        [-96.18771046],
#        [-95.12345883],
#        [-91.73565079],
#        [-91.38766552],
#        [-91.18378687],
#        [-90.61571309],
#        [-87.28548155],
#        [-84.85142967],
#        [-84.31679612],
#        [-84.14729259],
#        [-82.2825056 ],
#        [-82.10240859],
#        [-80.48408121],
#        [-79.8943894 ],
#        [-79.47407608],
#        [-74.84520954],
#        [-74.01353016],
#        [-73.52773654],
#        [-72.10423229],
#        [-71.7792529 ],
#        [-71.32444053],
#        [-70.56327712],
#        [-70.11596317],
#        [-68.86836292],
#        [-68.03979318],
#        [-61.83065804],
#        [-61.24383385],
#        [-53.18533166],
#        [-52.6924566 ],
#        [-47.29508955],
#        [-46.73031743],
#        [-45.08606882],
#        [-44.53910909],
#        [-44.26411725],
#        [-43.81021203],
#        [-42.82717317],
#        [-40.71694255],
#        [-39.86438207],
#        [-38.66665327],
#        [-34.64969017],
#        [-34.57106343],
#        [-34.5240855 ],
#        [-33.71639317],
#        [-28.68401095],
#        [-23.49570357],
#        [-20.16859543],
#        [-16.13468383],
#        [ -9.1782014 ],
#        [ -6.55072134],
#        [ -5.61211391],
#        [ -5.52888468],
#        [ -4.02621318],
#        [ -0.63968035],
#        [  0.73840564],
#        [  4.17045507],
#        [  4.37519797],
#        [  5.33053705],
#        [  5.92687727],
#        [  8.17827962],
#        [ 12.22043278],
#        [ 14.10955994],
#        [ 16.00786002],
#        [ 22.91712816],
#        [ 23.00713955],
#        [ 27.00455635],
#        [ 27.14730156],
#        [ 28.56720863],
#        [ 32.27512104],
#        [ 32.74676298],
#        [ 34.35018299],
#        [ 39.13178169],
#        [ 40.09688125],
#        [ 41.86066113],
#        [ 45.85687543],
#        [ 47.19991741],
#        [ 48.71894228],
#        [ 51.86201762],
#        [ 52.80353007],
#        [ 53.45546672],
#        [ 61.69524493],
#        [ 62.93217911],
#        [ 63.47776206],
#        [ 64.32498458],
#        [ 64.7961046 ],
#        [ 71.15373798],
#        [ 71.58278732],
#        [ 73.03922145],
#        [ 75.34417907],
#        [ 76.47233208],
#        [ 78.31537347],
#        [ 85.18453934],
#        [ 87.97975515],
#        [ 88.95451379],
#        [ 92.71752973],
#        [ 94.17138509],
#        [ 95.81334007],
#        [ 96.1470864 ],
#        [ 96.86592127],
#        [ 98.37794005]])

# %%
y_train = np.pi * np.array([np.sin(x_train).ravel(), np.cos(x_train).ravel()])
y_train = y_train.transpose() #旋转
y_train[::5] += np.random.rand(20, 2) #加入垃圾数据

# %%
plt.scatter(y_train[:, 0], y_train[:, 1])
plt.axis("equal")
# Out:
# (-3.502746736828114, 4.265841763069637, -3.498813627708629, 4.062855151334374)

# %%
tree1 = DecisionTreeRegressor(max_depth = 5)
tree2 = DecisionTreeRegressor(max_depth = 10)
tree3 = DecisionTreeRegressor(max_depth = 50)
tree1.fit(x_train, y_train)
tree2.fit(x_train, y_train)
tree3.fit(x_train, y_train)
plt.plot(x_train, y_train)
# Out:
# [<matplotlib.lines.Line2D at 0x2867315ec50>,
#  <matplotlib.lines.Line2D at 0x2867315eda0>]

# %%
x_test = np.arange(-100, 100, 0.1).reshape((-1, 1))
x_test
# Out:
# array([[-100. ],
#        [ -99.9],
#        [ -99.8],
#        ...,
#        [  99.7],
#        [  99.8],
#        [  99.9]])

# %%
x_test.shape
# Out:
# (2000, 1)

# %%
y_new1 = tree1.predict(x_test)
y_new2 = tree2.predict(x_test)
y_new3 = tree3.predict(x_test)

# %%
fig = plt.figure(figsize=(12, 9)) #设置大小
axes1 = fig.add_subplot(221)
s1 = axes1.scatter(y_train[:, 0], y_train[:, 1], label="orignal")
axes1.legend()

axes2 = fig.add_subplot(222)
s2 = axes2.scatter(y_new1[:, 0], y_new1[:, 1], label="max_depth=5")
axes2.legend()

axes3 = fig.add_subplot(223)
s3 = axes3.scatter(y_new2[:, 0], y_new2[:, 1], label="max_depth=10")
axes3.legend()

axes4 = fig.add_subplot(224)
s4 = axes4.scatter(y_new3[:, 0], y_new3[:, 1], label="max_depth=50")
axes4.legend()

fig.legend((s1, s2, s3, s4),("1", "2", "3", "4"), "upper right")
